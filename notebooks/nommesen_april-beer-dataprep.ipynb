# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import StandardScaler, LabelEncoder
#OrdinalEncoder

# %% [markdown]
# ## Data Transformations

# %%
#Solution
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df_raw_beer = pd.read_csv('/wd/data/raw/beer_reviews.csv')

# %%
df_cleaned = df_raw_beer.copy()
df_cleaned.drop(['brewery_id',
                 'review_profilename', 
                 'review_time',
                 'beer_name',
                 'beer_beerid'
                ], axis=1, inplace=True)
df_cleaned.head()
# Out:
#               brewery_name  review_overall  review_aroma  review_appearance  \
# 0          Vecchio Birraio             1.5           2.0                2.5
# 1          Vecchio Birraio             3.0           2.5                3.0
# 2          Vecchio Birraio             3.0           2.5                3.0
# 3          Vecchio Birraio             3.0           3.0                3.5
# 4  Caldera Brewing Company             4.0           4.5                4.0
#
#                        beer_style  review_palate  review_taste  beer_abv
# 0                      Hefeweizen            1.5           1.5       5.0
# 1              English Strong Ale            3.0           3.0       6.2
# 2          Foreign / Export Stout            3.0           3.0       6.5
# 3                 German Pilsener            2.5           3.0       5.0
# 4  American Double / Imperial IPA            4.0           4.5       7.7

# %%
# Create a numeric version of the categorical features 
le = LabelEncoder()

cats_dict = dict(enumerate(df_cleaned.brewery_name.unique()))
df_cleaned['brewery_name'] = le.fit_transform(df_cleaned['brewery_name'])
df_cleaned
# Out:
#          brewery_name  review_overall  review_aroma  review_appearance  \
# 0                5438             1.5           2.0                2.5
# 1                5438             3.0           2.5                3.0
# 2                5438             3.0           2.5                3.0
# 3                5438             3.0           3.0                3.5
# 4                1480             4.0           4.5                4.0
# ...               ...             ...           ...                ...
# 1586609          5128             5.0           4.0                3.5
# 1586610          5128             4.0           5.0                2.5
# 1586611          5128             4.5           3.5                3.0
# 1586612          5128             4.0           4.5                4.5
# 1586613          5128             5.0           4.5                4.5
#
#                              beer_style  review_palate  review_taste  beer_abv
# 0                            Hefeweizen            1.5           1.5       5.0
# 1                    English Strong Ale            3.0           3.0       6.2
# 2                Foreign / Export Stout            3.0           3.0       6.5
# 3                       German Pilsener            2.5           3.0       5.0
# 4        American Double / Imperial IPA            4.0           4.5       7.7
# ...                                 ...            ...           ...       ...
# 1586609                     Pumpkin Ale            4.0           4.0       5.2
# 1586610                     Pumpkin Ale            2.0           4.0       5.2
# 1586611                     Pumpkin Ale            3.5           4.0       5.2
# 1586612                     Pumpkin Ale            4.5           4.5       5.2
# 1586613                     Pumpkin Ale            4.5           4.5       5.2
#
# [1586614 rows x 8 columns]

# %%
# Standardise the numeric features 

num_cols = ['brewery_name',
            'review_overall',
            'review_aroma',
            'review_appearance',
            'review_palate',
            'review_taste',
            'beer_abv']
sc = StandardScaler()
df_cleaned[num_cols] = sc.fit_transform(df_cleaned[num_cols])

df_cleaned.head()
# Out:
#    brewery_name  review_overall  review_aroma  review_appearance  \
# 0      1.464266       -3.213310     -2.487952          -2.177663
# 1      1.464266       -1.131774     -1.771225          -1.366096
# 2      1.464266       -1.131774     -1.771225          -1.366096
# 3      1.464266       -1.131774     -1.054499          -0.554530
# 4     -0.823942        0.255917      1.095679           0.257037
#
#                        beer_style  review_palate  review_taste  beer_abv
# 0                      Hefeweizen      -3.288833     -3.132454 -0.879382
# 1              English Strong Ale      -1.090123     -1.083188 -0.362703
# 2          Foreign / Export Stout      -1.090123     -1.083188 -0.233533
# 3                 German Pilsener      -1.823026     -1.083188 -0.879382
# 4  American Double / Imperial IPA       0.375684      0.966078  0.283146

# %%
# Create a numeric (integer) version of the target variable 

cats_dict = dict(enumerate(df_cleaned.beer_style.unique()))
le = LabelEncoder()
df_cleaned['beer_style'] = le.fit_transform(df_cleaned['beer_style'])
df_cleaned
# Out:
#          brewery_name  review_overall  review_aroma  review_appearance  \
# 0            1.464266       -3.213310     -2.487952          -2.177663
# 1            1.464266       -1.131774     -1.771225          -1.366096
# 2            1.464266       -1.131774     -1.771225          -1.366096
# 3            1.464266       -1.131774     -1.054499          -0.554530
# 4           -0.823942        0.255917      1.095679           0.257037
# ...               ...             ...           ...                ...
# 1586609      1.285049        1.643608      0.378953          -0.554530
# 1586610      1.285049        0.255917      1.812405          -2.177663
# 1586611      1.285049        0.949762     -0.337773          -1.366096
# 1586612      1.285049        0.255917      1.095679           1.068603
# 1586613      1.285049        1.643608      1.095679           1.068603
#
#          beer_style  review_palate  review_taste  beer_abv
# 0                65      -3.288833     -3.132454 -0.879382
# 1                51      -1.090123     -1.083188 -0.362703
# 2                59      -1.090123     -1.083188 -0.233533
# 3                61      -1.823026     -1.083188 -0.879382
# 4                 9       0.375684      0.966078  0.283146
# ...             ...            ...           ...       ...
# 1586609          85       0.375684      0.282989 -0.793269
# 1586610          85      -2.555929      0.282989 -0.793269
# 1586611          85      -0.357219      0.282989 -0.793269
# 1586612          85       1.108588      0.966078 -0.793269
# 1586613          85       1.108588      0.966078 -0.793269
#
# [1586614 rows x 8 columns]

# %% [markdown]
# ## Split the data

# %%
from src.data.sets import split_sets_random, save_sets

# Split the data into training and testing sets with 80-20 ratio
X_train, y_train, X_val, y_val, X_test, y_test = split_sets_random(df_cleaned,
                                                                   target_col='beer_style',
                                                                   test_ratio=0.2)

# %%
# !mkdir ../data/processed/beer_type

# %%
save_sets(X_train=X_train,
          y_train=y_train,
          X_val=X_val,
          y_val=y_val,
          X_test=X_test,
          y_test=y_test,
          path='/wd/data/processed/beer_type/'
         )

# %%
# Import this class from src/models/pytorch and convert all sets to PytorchDataset

from src.models.pytorch import PytorchDataset

train_dataset = PytorchDataset(X=X_train, y=y_train)
val_dataset = PytorchDataset(X=X_val, y=y_val)
test_dataset = PytorchDataset(X=X_test, y=y_test)

# %% [markdown]
# ## Baseline Model

# %%
# Import NullModel from src.models.null
from src.models.null import NullModel

baseline_model = NullModel(target_type='classification')
y_base = baseline_model.fit_predict(y_train)
# Out:
# /wd/src/models/null.py:43: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   self.pred_value = mode(y)[0][0]

# %%
# Import print_class_perf from src.models.performance
from src.models.performance import print_class_perf

# Print the classification metrics for this baseline model
print_class_perf(y_base, y_train, set_name='Training', average='weighted')
# Out:
# Accuracy Training: 0.0742157299405022
# F1 Training: 0.01025487603110527
